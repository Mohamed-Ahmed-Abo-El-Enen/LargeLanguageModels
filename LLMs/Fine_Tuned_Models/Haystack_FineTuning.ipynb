# %%
# !pip install transformers
# !pip install datasets
# !pip install accelerator
# !pip install farm-haystack[colab,preprocessing,elasticsearch,inference,metrics]
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)
# Collecting datasets
#   Downloading datasets-2.16.1-py3-none-any.whl (507 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (10.0.1)
# Collecting pyarrow-hotfix (from datasets)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.1)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.19.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: pyarrow-hotfix, dill, multiprocess, datasets
# Successfully installed datasets-2.16.1 dill-0.3.7 multiprocess-0.70.15 pyarrow-hotfix-0.6
# Collecting accelerator
#   Downloading accelerator-2023.11.3.dev1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 9.5 MB/s eta 0:00:00
# Collecting setproctitle>=1.1.8 (from accelerator)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Collecting bottle<0.13,>=0.12.7 (from accelerator)
#   Downloading bottle-0.12.25-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.2/90.2 kB 12.8 MB/s eta 0:00:00
# Collecting waitress>=1.0 (from accelerator)
#   Downloading waitress-2.1.2-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 9.0 MB/s eta 0:00:00
# Installing collected packages: bottle, waitress, setproctitle, accelerator
# Successfully installed accelerator-2023.11.3.dev1 bottle-0.12.25 setproctitle-1.3.3 waitress-2.1.2
# Collecting farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]
#   Downloading farm_haystack-1.23.0-py3-none-any.whl (764 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 764.4/764.4 kB 6.4 MB/s eta 0:00:00
# Collecting boilerpy3 (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading boilerpy3-1.0.7-py3-none-any.whl (22 kB)
# Collecting events (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading Events-0.5-py3-none-any.whl (6.8 kB)
# Collecting httpx (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading httpx-0.26.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (4.19.2)
# Collecting lazy-imports==0.3.1 (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading lazy_imports-0.3.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (10.1.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (3.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (1.5.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (9.4.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (4.1.0)
# Collecting posthog (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading posthog-3.1.0-py2.py3-none-any.whl (37 kB)
# Collecting prompthub-py==4.0.0 (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading prompthub_py-4.0.0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: pydantic<2 in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (1.10.13)
# Collecting quantulum3 (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading quantulum3-0.9.0-py3-none-any.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 30.1 MB/s eta 0:00:00
# Collecting rank-bm25 (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (2.31.0)
# Collecting requests-cache<1.0.0 (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading requests_cache-0.9.8-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.7/48.7 kB 2.4 MB/s eta 0:00:00
# Collecting scikit-learn>=1.3.0 (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading scikit_learn-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 69.5 MB/s eta 0:00:00
# Collecting sseclient-py (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading sseclient_py-1.8.0-py2.py3-none-any.whl (8.8 kB)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (8.2.3)
# Collecting tiktoken>=0.5.1 (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading tiktoken-0.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 77.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (4.66.1)
# Requirement already satisfied: transformers==4.35.2 in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (4.35.2)
# Requirement already satisfied: huggingface-hub>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (0.19.4)
# Collecting sentence-transformers>=2.2.0 (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 13.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting langdetect (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 76.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (3.8.1)
# Collecting pillow (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading Pillow-9.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 90.5 MB/s eta 0:00:00
# Collecting mlflow (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading mlflow-2.9.2-py3-none-any.whl (19.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 23.8 MB/s eta 0:00:00
# Collecting rapidfuzz<2.8.0,>=2.0.15 (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading rapidfuzz-2.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 95.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (1.11.4)
# Collecting seqeval (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyyaml<7.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from prompthub-py==4.0.0->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (6.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (23.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (0.4.1)
# Collecting sentencepiece!=0.1.92,>=0.1.91 (from transformers==4.35.2->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 78.3 MB/s eta 0:00:00
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (3.20.3)
# Requirement already satisfied: torch!=1.12.0,>=1.10 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (2.1.0+cu121)
# Collecting accelerate>=0.20.3 (from transformers==4.35.2->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading accelerate-0.25.0-py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 36.1 MB/s eta 0:00:00
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.5.0->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.5.0->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (4.5.0)
# Collecting jarowinkler<2.0.0,>=1.2.0 (from rapidfuzz<2.8.0,>=2.0.15->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading jarowinkler-1.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 16.1 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (2023.11.17)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from requests-cache<1.0.0->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (1.4.4)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache<1.0.0->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (23.1.0)
# Collecting cattrs>=22.2 (from requests-cache<1.0.0->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading cattrs-23.2.3-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 8.5 MB/s eta 0:00:00
# Collecting url-normalize>=1.4 (from requests-cache<1.0.0->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.0->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.0->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (3.2.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.0->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (0.16.0+cu121)
# Collecting elastic-transport<8 (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading elastic_transport-7.16.0-py2.py3-none-any.whl (35 kB)
# Collecting elasticsearch<8,>=7.17 (from farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading elasticsearch-7.17.9-py2.py3-none-any.whl (385 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.0/386.0 kB 38.6 MB/s eta 0:00:00
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (3.7.1)
# Collecting httpcore==1.* (from httpx->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading httpcore-1.0.2-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (1.3.0)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (0.32.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (0.15.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (1.16.0)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in /usr/local/lib/python3.10/dist-packages (from mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (2.2.1)
# Collecting databricks-cli<1,>=0.8.7 (from mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading databricks_cli-0.18.0-py2.py3-none-any.whl (150 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.3/150.3 kB 20.6 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints<1 in /usr/local/lib/python3.10/dist-packages (from mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (0.4)
# Collecting gitpython<4,>=2.1.0 (from mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 22.9 MB/s eta 0:00:00
# Requirement already satisfied: pytz<2024 in /usr/local/lib/python3.10/dist-packages (from mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (2023.3.post1)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (7.0.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (0.4.4)
# Collecting alembic!=1.10.0,<2 (from mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 27.3 MB/s eta 0:00:00
# Collecting docker<7,>=4.0.0 (from mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading docker-6.1.3-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 19.2 MB/s eta 0:00:00
# Requirement already satisfied: Flask<4 in /usr/local/lib/python3.10/dist-packages (from mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (2.2.5)
# Collecting querystring-parser<2 (from mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (2.0.23)
# Requirement already satisfied: pyarrow<15,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (10.0.1)
# Requirement already satisfied: markdown<4,>=3.3 in /usr/local/lib/python3.10/dist-packages (from mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (3.5.1)
# Requirement already satisfied: matplotlib<4 in /usr/local/lib/python3.10/dist-packages (from mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (3.7.1)
# Collecting gunicorn<22 (from mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading gunicorn-21.2.0-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 11.6 MB/s eta 0:00:00
# Requirement already satisfied: Jinja2<4,>=2.11 in /usr/local/lib/python3.10/dist-packages (from mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (2.8.2)
# Collecting monotonic>=1.5 (from posthog->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0 (from posthog->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: inflect in /usr/local/lib/python3.10/dist-packages (from quantulum3->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (7.0.0)
# Collecting num2words (from quantulum3->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading num2words-0.5.13-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.3/143.3 kB 19.0 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.20.3->transformers==4.35.2->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (5.9.5)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading Mako-1.3.0-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache<1.0.0->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (1.2.0)
# Requirement already satisfied: pyjwt>=1.7.0 in /usr/lib/python3/dist-packages (from databricks-cli<1,>=0.8.7->mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (2.3.0)
# Requirement already satisfied: oauthlib>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from databricks-cli<1,>=0.8.7->mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (3.2.2)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from databricks-cli<1,>=0.8.7->mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (0.9.0)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from docker<7,>=4.0.0->mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (1.7.0)
# Collecting urllib3<3,>=1.21.1 (from requests->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 19.1 MB/s eta 0:00:00
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from Flask<4->mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (3.0.1)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask<4->mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (2.1.2)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=2.1.0->mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2<4,>=2.11->mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4->mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4->mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4->mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4->mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4->mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (3.1.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (3.0.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers==4.35.2->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (1.12)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers==4.35.2->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (2.1.0)
# Collecting docopt>=0.6.2 (from num2words->quantulum3->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing])
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch!=1.12.0,>=1.10->transformers==4.35.2->farm-haystack[colab,elasticsearch,inference,metrics,preprocessing]) (1.3.0)
# Building wheels for collected packages: sentence-transformers, langdetect, seqeval, docopt
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=00a91ca6e8decc702a9d410a7ed38022c912abef2de9105134fb9bd0adc56f07
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993225 sha256=4b71e9eed1bc58ed4d58cb477e4df0b45d13e2ded38f665db5a95723802cf4c6
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=22b4b1551794e09e655b2993da76fdb9483208e686b61d432d8112294dd2eab7
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=0a5650f8eb8d7628c12e9317f69767d7bfe54fe3810e4c24f438a46609612295
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built sentence-transformers langdetect seqeval docopt
# Installing collected packages: sseclient-py, sentencepiece, monotonic, events, docopt, urllib3, url-normalize, smmap, rank-bm25, querystring-parser, pillow, num2words, Mako, lazy-imports, langdetect, jarowinkler, h11, gunicorn, cattrs, boilerpy3, backoff, scikit-learn, rapidfuzz, httpcore, gitdb, elasticsearch, elastic-transport, alembic, tiktoken, seqeval, requests-cache, quantulum3, prompthub-py, posthog, httpx, gitpython, docker, databricks-cli, mlflow, accelerate, sentence-transformers, farm-haystack
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# Successfully installed Mako-1.3.0 accelerate-0.25.0 alembic-1.13.1 backoff-2.2.1 boilerpy3-1.0.7 cattrs-23.2.3 databricks-cli-0.18.0 docker-6.1.3 docopt-0.6.2 elastic-transport-7.16.0 elasticsearch-7.17.9 events-0.5 farm-haystack-1.23.0 gitdb-4.0.11 gitpython-3.1.40 gunicorn-21.2.0 h11-0.14.0 httpcore-1.0.2 httpx-0.26.0 jarowinkler-1.2.3 langdetect-1.0.9 lazy-imports-0.3.1 mlflow-2.9.2 monotonic-1.6 num2words-0.5.13 pillow-9.0.0 posthog-3.1.0 prompthub-py-4.0.0 quantulum3-0.9.0 querystring-parser-1.2.4 rank-bm25-0.2.2 rapidfuzz-2.7.0 requests-cache-0.9.8 scikit-learn-1.3.2 sentence-transformers-2.2.2 sentencepiece-0.1.99 seqeval-1.2.2 smmap-5.0.1 sseclient-py-1.8.0 tiktoken-0.5.2 url-normalize-1.4.3 urllib3-1.26.18

# %%
from datasets import load_dataset

dataset = load_dataset("lavita/ChatDoctor-HealthCareMagic-100k")
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['instruction', 'input', 'output'],
#         num_rows: 112165
#     })
# })

# %%
test_size = 0.2

dataset = dataset["train"].train_test_split(test_size=test_size)
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['instruction', 'input', 'output'],
#         num_rows: 89732
#     })
#     test: Dataset({
#         features: ['instruction', 'input', 'output'],
#         num_rows: 22433
#     })
# })

# %%
train_df = dataset["train"].to_pandas()
test_df = dataset["test"].to_pandas()

# %%
import pandas as pd
import numpy as np

def generate_squad_columns(df, title):
    df.reset_index(inplace = True)
    df.rename(columns={"index": "id", "input": "question", "output": "answer"}, inplace=True)
    df["review_id"] = df["id"].apply(lambda x: f"Doc_Case_{x}")
    df["title"] = title
    df["is_impossible"] = df.apply(lambda row: False if row["answer"]=='' or pd.isnull(row["answer"]) else True, axis=1)
    df["context"] = df["question"] + ' ' + df["answer"]
    df["answer_start"] = df["question"].apply(lambda x: len(x)+1)
    df.drop(columns=["instruction"], inplace=True)
    return df

# %%
train_df = generate_squad_columns(train_df, "DoctorChat")
test_df = generate_squad_columns(test_df, "DoctorChat")

# %%
test_df["context"][0]
# Out:
# 'I treated myself for a yeast infection and it didnt work, I have excess white stuff and I do not smell normal, almost like milk about to go bad. My boyfriend smells like fish sometimes I can not even stand it. I think we have something. What could it be? I welcome you at my virtual clinic! Thanks for consulting me at Chat Doctor. I have thoroughly worked through your case, and I can easily realize your health worries. Being your physician, I assure you not to worry as things will settle down very soon. Causes of your condition may be'

# %%
test_df["question"][0]
# Out:
# 'I treated myself for a yeast infection and it didnt work, I have excess white stuff and I do not smell normal, almost like milk about to go bad. My boyfriend smells like fish sometimes I can not even stand it. I think we have something. What could it be?'

# %%
test_df["answer"][0]
# Out:
# 'I welcome you at my virtual clinic! Thanks for consulting me at Chat Doctor. I have thoroughly worked through your case, and I can easily realize your health worries. Being your physician, I assure you not to worry as things will settle down very soon. Causes of your condition may be'

# %%
def create_paragraphs(df):
    paragraphs = []
    id2context = dict(zip(df["review_id"], df["context"]))

    for review_id, review in id2context.items():
        qas = []
        # Filter for all question-answer pairs about a specific context
        review_df = df.query(f"review_id == '{review_id}'")
        id2question = dict(zip(review_df["id"], review_df["question"]))

        # Build up the qas array
        for qid, question in id2question.items():
            # Filter for a single question ID
            question_df = df.query(f"id == {qid}").to_dict(orient="list")

            ans_start_idxs = question_df["answer_start"]
            ans_text = question_df["answer"]

            # Fill answerable questions
            if len(ans_start_idxs):
                answers = [
                    {"text": text, "answer_start": answer_start}
                    for text, answer_start in zip(ans_text, ans_start_idxs)]
                is_impossible = False
            else:
                answers = []
                is_impossible = True

            # Add question-answer pairs to qas
            qas.append({"question": question,
                        "id": qid,
                        "is_impossible": is_impossible,
                        "answers": answers})

        # Add context and question-answer pairs to paragraphs
        paragraphs.append({"qas": qas, "context": review})
    return paragraphs

# %%
import json

def convert_to_squad(dfs):
    for split, df in dfs.items():
        subjqa_data = {}
        # Create 'paragraphs' for each product ID
        groups = (df.groupby("title").apply(create_paragraphs)
            .to_frame(name="paragraphs").reset_index())

        subjqa_data["data"] = groups.to_dict(orient="records")

        # Save the result to disk
        with open(f"medical_chat-{split}.json", "w+", encoding="utf-8") as f:
            json.dump(subjqa_data, f)

# %%
dfs = {"train": train_df,
       "test": test_df}

# %%
convert_to_squad(dfs)

# %%
import torch
torch.cuda.empty_cache()

# %%
from haystack.nodes import FARMReader

# %%
from haystack.nodes import FARMReader

max_seq_length, doc_stride = 512, 256

reader = FARMReader(model_name_or_path="deepset/roberta-base-squad2",
                    use_gpu=True,
                    return_no_answer=True,
                    #doc_stride=doc_stride
                    max_seq_len=max_seq_length)

# %%
data_dir = "."

reader.train(data_dir=data_dir,
             train_filename="medical_chat-train.json",
             use_gpu=True,
             n_epochs=10,
             save_dir="model",
             dev_filename="medical_chat-test.json",
             batch_size=8)
# Out:
# Preprocessing dataset:   0%|          | 0/176 [00:00<?, ? Dicts/s]Token indices sequence length is longer than the specified maximum sequence length for this model (620 > 512). Running this sequence through the model will result in indexing errors
# Preprocessing dataset: 100%|██████████| 176/176 [02:31<00:00,  1.16 Dicts/s]
# ERROR:haystack.modeling.data_handler.processor:Unable to convert 6 samples to features. Their ids are : 470-0-0, 486-0-0, 355-0-0, 444-0-0, 452-0-0, 465-0-0
# Preprocessing dataset: 100%|██████████| 44/44 [00:37<00:00,  1.17 Dicts/s]
# ERROR:haystack.modeling.data_handler.processor:Unable to convert 9 samples to features. Their ids are : 408-0-0, 470-0-0, 385-0-0, 486-0-0, 355-0-0, 444-0-0, 236-0-0, 452-0-0, 465-0-0
# Train epoch 0/9 (Cur. train loss: 4.2165):   3%|▎         | 300/11518 [04:03<2:30:48,  1.24it/s]
# Evaluating:   0%|          | 0/2885 [00:00<?, ?it/s]
# Evaluating:   1%|          | 35/2885 [00:10<13:54,  3.42it/s]
# Evaluating:   2%|▏         | 72/2885 [00:20<13:09,  3.56it/s]
# Evaluating:   4%|▍         | 109/2885 [00:30<12:49,  3.61it/s]
# Evaluating:   5%|▌         | 146/2885 [00:40<12:35,  3.63it/s]
# Evaluating:   6%|▋         | 185/2885 [00:50<12:11,  3.69it/s]
# Evaluating:   8%|▊         | 224/2885 [01:01<11:53,  3.73it/s]
# Evaluating:   9%|▉         | 262/2885 [01:11<11:47,  3.71it/s]
# Evaluating:  10%|█         | 299/2885 [01:21<11:41,  3.69it/s]
# Evaluating:  12%|█▏        | 336/2885 [01:31<11:34,  3.67it/s]
# Evaluating:  13%|█▎        | 373/2885 [01:41<11:22,  3.68it/s]
# Evaluating:  14%|█▍        | 410/2885 [01:51<11:14,  3.67it/s]
# Evaluating:  16%|█▌        | 448/2885 [02:02<11:02,  3.68it/s]
# Evaluating:  17%|█▋        | 487/2885 [02:12<10:43,  3.73it/s]
# Evaluating:  18%|█▊        | 526/2885 [02:22<10:35,  3.71it/s]
# Evaluating:  20%|█▉        | 563/2885 [02:33<10:27,  3.70it/s]
# Evaluating:  21%|██        | 600/2885 [02:43<10:20,  3.68it/s]
# Evaluating:  22%|██▏       | 637/2885 [02:53<10:12,  3.67it/s]
# Evaluating:  23%|██▎       | 674/2885 [03:03<10:03,  3.66it/s]
# Evaluating:  74%|███████▎  | 2123/2885 [09:39<03:29,  3.64it/s]
# Evaluating:  75%|███████▍  | 2160/2885 [09:49<03:19,  3.64it/s]
# Evaluating:  76%|███████▌  | 2197/2885 [10:00<03:09,  3.64it/s]
# Evaluating:  77%|███████▋  | 2234/2885 [10:10<02:59,  3.64it/s]
# Evaluating:  79%|███████▊  | 2271/2885 [10:20<02:49,  3.63it/s]
# Evaluating:  80%|████████  | 2308/2885 [10:30<02:38,  3.63it/s]
# Evaluating:  81%|████████▏ | 2345/2885 [10:40<02:28,  3.63it/s]
# Evaluating:  83%|████████▎ | 2382/2885 [10:50<02:18,  3.64it/s]
# Evaluating:  84%|████████▍ | 2419/2885 [11:01<02:08,  3.64it/s]
# Evaluating:  85%|████████▌ | 2456/2885 [11:11<01:59,  3.60it/s]
# Evaluating:  86%|████████▋ | 2492/2885 [11:21<01:49,  3.58it/s]
# Evaluating:  88%|████████▊ | 2528/2885 [11:31<01:39,  3.58it/s]
# Evaluating:  89%|████████▉ | 2565/2885 [11:41<01:28,  3.61it/s]
# Evaluating:  90%|█████████ | 2602/2885 [11:51<01:17,  3.63it/s]
# Evaluating:  91%|█████████▏| 2639/2885 [12:02<01:07,  3.64it/s]
# Evaluating:  93%|█████████▎| 2676/2885 [12:12<00:57,  3.64it/s]
# Evaluating:  94%|█████████▍| 2713/2885 [12:22<00:47,  3.64it/s]
# Evaluating:  95%|█████████▌| 2750/2885 [12:32<00:37,  3.64it/s]
# Evaluating:  97%|█████████▋| 2787/2885 [12:42<00:26,  3.64it/s]
# Evaluating:  98%|█████████▊| 2824/2885 [12:52<00:16,  3.65it/s]
# Evaluating: 100%|██████████| 2885/2885 [13:09<00:00,  3.65it/s]
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Train epoch 0/9 (Cur. train loss: 2.1226):   5%|▌         | 600/11518 [21:03<2:17:58,  1.32it/s]
# Evaluating:   0%|          | 0/2885 [00:00<?, ?it/s]
# Evaluating:   1%|▏         | 37/2885 [00:10<12:51,  3.69it/s]
# Evaluating:   3%|▎         | 76/2885 [00:20<12:19,  3.80it/s]
# Evaluating:   4%|▍         | 115/2885 [00:30<12:04,  3.82it/s]
# Evaluating:   5%|▌         | 154/2885 [00:40<11:52,  3.84it/s]
# Evaluating:   7%|▋         | 193/2885 [00:50<11:40,  3.84it/s]
# Evaluating:   8%|▊         | 232/2885 [01:00<11:27,  3.86it/s]
# Evaluating:   9%|▉         | 271/2885 [01:10<11:16,  3.86it/s]
# Evaluating:  11%|█         | 310/2885 [01:20<11:06,  3.87it/s]
# Evaluating:  12%|█▏        | 349/2885 [01:30<10:55,  3.87it/s]
# Evaluating:  13%|█▎        | 388/2885 [01:40<10:45,  3.87it/s]
# Evaluating:  15%|█▍        | 427/2885 [01:50<10:34,  3.87it/s]
# Evaluating:  16%|█▌        | 466/2885 [02:00<10:24,  3.87it/s]
# Evaluating:  18%|█▊        | 505/2885 [02:10<10:14,  3.87it/s]
# Evaluating:  19%|█▉        | 544/2885 [02:21<10:04,  3.87it/s]
# Evaluating:  20%|██        | 583/2885 [02:31<09:54,  3.87it/s]
# Evaluating:  74%|███████▍  | 2143/2885 [09:13<03:11,  3.88it/s]
# Evaluating:  76%|███████▌  | 2182/2885 [09:23<03:01,  3.88it/s]
# Evaluating:  77%|███████▋  | 2221/2885 [09:33<02:51,  3.88it/s]
# Evaluating:  78%|███████▊  | 2260/2885 [09:44<02:40,  3.88it/s]
# Evaluating:  80%|███████▉  | 2299/2885 [09:54<02:30,  3.88it/s]
# Evaluating:  81%|████████  | 2338/2885 [10:04<02:21,  3.88it/s]
# Evaluating:  82%|████████▏ | 2377/2885 [10:14<02:11,  3.87it/s]
# Evaluating:  84%|████████▎ | 2416/2885 [10:24<02:01,  3.87it/s]
# Evaluating:  85%|████████▌ | 2455/2885 [10:34<01:51,  3.87it/s]
# Evaluating:  86%|████████▋ | 2494/2885 [10:44<01:41,  3.87it/s]
# Evaluating:  88%|████████▊ | 2533/2885 [10:54<01:30,  3.87it/s]
# Evaluating:  89%|████████▉ | 2572/2885 [11:04<01:20,  3.87it/s]
# Evaluating:  91%|█████████ | 2611/2885 [11:14<01:10,  3.88it/s]
# Evaluating:  92%|█████████▏| 2650/2885 [11:24<01:00,  3.88it/s]
# Evaluating:  93%|█████████▎| 2689/2885 [11:34<00:50,  3.88it/s]
# Evaluating:  95%|█████████▍| 2728/2885 [11:44<00:40,  3.88it/s]
# Evaluating:  96%|█████████▌| 2767/2885 [11:54<00:30,  3.87it/s]
# Evaluating:  97%|█████████▋| 2806/2885 [12:05<00:20,  3.87it/s]
# Evaluating:  99%|█████████▊| 2845/2885 [12:15<00:10,  3.87it/s]
# Evaluating: 100%|██████████| 2885/2885 [12:25<00:00,  3.87it/s]
# Train epoch 0/9 (Cur. train loss: 1.3856):   8%|▊         | 900/11518 [37:24<2:13:49,  1.32it/s]
# Evaluating:   0%|          | 0/2885 [00:00<?, ?it/s]
# Evaluating:   1%|▏         | 38/2885 [00:10<12:48,  3.71it/s]
# Evaluating:   3%|▎         | 77/2885 [00:20<12:16,  3.81it/s]
# Evaluating:   4%|▍         | 116/2885 [00:30<12:01,  3.84it/s]
# Evaluating:   5%|▌         | 155/2885 [00:40<11:48,  3.85it/s]
# Evaluating:   7%|▋         | 194/2885 [00:50<11:38,  3.85it/s]
# Evaluating:   8%|▊         | 233/2885 [01:00<11:27,  3.86it/s]
# Evaluating:   9%|▉         | 272/2885 [01:10<11:16,  3.86it/s]
# Evaluating:  11%|█         | 311/2885 [01:20<11:06,  3.86it/s]
# Evaluating:  12%|█▏        | 350/2885 [01:30<10:56,  3.86it/s]
# Evaluating:  13%|█▎        | 389/2885 [01:40<10:46,  3.86it/s]
# Evaluating:  15%|█▍        | 428/2885 [01:51<10:35,  3.87it/s]
# Evaluating:  16%|█▌        | 467/2885 [02:01<10:25,  3.87it/s]
# Evaluating:  18%|█▊        | 506/2885 [02:11<10:15,  3.87it/s]
# Evaluating:  19%|█▉        | 545/2885 [02:21<10:04,  3.87it/s]
# Evaluating:  20%|██        | 584/2885 [02:31<09:54,  3.87it/s]
# Evaluating:  22%|██▏       | 623/2885 [02:41<09:44,  3.87it/s]
# Evaluating:  73%|███████▎  | 2115/2885 [09:16<03:35,  3.57it/s]
# Evaluating:  75%|███████▍  | 2152/2885 [09:26<03:24,  3.59it/s]
# Evaluating:  76%|███████▌  | 2189/2885 [09:37<03:12,  3.61it/s]
# Evaluating:  77%|███████▋  | 2226/2885 [09:47<03:01,  3.62it/s]
# Evaluating:  78%|███████▊  | 2263/2885 [09:57<02:51,  3.64it/s]
# Evaluating:  80%|███████▉  | 2300/2885 [10:07<02:40,  3.65it/s]
# Evaluating:  81%|████████  | 2337/2885 [10:17<02:29,  3.66it/s]
# Evaluating:  82%|████████▏ | 2374/2885 [10:27<02:19,  3.66it/s]
# Evaluating:  84%|████████▎ | 2411/2885 [10:37<02:09,  3.65it/s]
# Evaluating:  85%|████████▍ | 2448/2885 [10:47<01:59,  3.65it/s]
# Evaluating:  86%|████████▌ | 2485/2885 [10:57<01:49,  3.65it/s]
# Evaluating:  87%|████████▋ | 2522/2885 [11:07<01:39,  3.65it/s]
# Evaluating:  89%|████████▊ | 2559/2885 [11:18<01:29,  3.66it/s]
# Evaluating:  90%|████████▉ | 2596/2885 [11:28<01:18,  3.66it/s]
# Evaluating:  91%|█████████▏| 2633/2885 [11:38<01:08,  3.67it/s]
# Evaluating:  93%|█████████▎| 2670/2885 [11:48<00:58,  3.67it/s]
# Evaluating:  94%|█████████▍| 2707/2885 [11:58<00:48,  3.66it/s]
# Evaluating:  95%|█████████▌| 2744/2885 [12:08<00:38,  3.66it/s]
# Evaluating:  96%|█████████▋| 2781/2885 [12:18<00:28,  3.66it/s]
# Evaluating:  98%|█████████▊| 2818/2885 [12:28<00:18,  3.66it/s]
# Evaluating: 100%|██████████| 2885/2885 [12:47<00:00,  3.76it/s]
# Train epoch 0/9 (Cur. train loss: 0.6788):  10%|█         | 1200/11518 [54:18<2:09:58,  1.32it/s]
# Evaluating:   0%|          | 0/2885 [00:00<?, ?it/s]
# Evaluating:   1%|▏         | 38/2885 [00:10<12:48,  3.70it/s]
# Evaluating:   3%|▎         | 77/2885 [00:20<12:16,  3.81it/s]
# Evaluating:   4%|▍         | 116/2885 [00:30<11:59,  3.85it/s]
# Evaluating:   5%|▌         | 155/2885 [00:40<11:47,  3.86it/s]
# Evaluating:   7%|▋         | 194/2885 [00:50<11:35,  3.87it/s]
# Evaluating:   8%|▊         | 233/2885 [01:00<11:25,  3.87it/s]
# Evaluating:   9%|▉         | 272/2885 [01:10<11:15,  3.87it/s]
# Evaluating:  11%|█         | 311/2885 [01:20<11:05,  3.87it/s]
# Evaluating:  12%|█▏        | 350/2885 [01:30<10:55,  3.87it/s]
# Evaluating:  13%|█▎        | 389/2885 [01:40<10:45,  3.87it/s]
# Evaluating:  15%|█▍        | 428/2885 [01:50<10:34,  3.87it/s]
# Evaluating:  16%|█▌        | 467/2885 [02:00<10:24,  3.87it/s]
# Evaluating:  18%|█▊        | 506/2885 [02:10<10:13,  3.88it/s]
# Evaluating:  19%|█▉        | 545/2885 [02:20<10:02,  3.88it/s]

# %%
del reader

# %%
reader = FARMReader(model_name_or_path="model")

# %%
reader.predict_on_texts(question=test_df["question"][0],
                        texts=[test_df["context"][0]])
